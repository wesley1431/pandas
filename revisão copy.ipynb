# %%
import pandas as pd

# %%
url = "dataset/revisao_pandas.csv"
pd.read_csv(url)
# Out:
#                        DataSet:
# Nome      Idade Notas  Aprovado
# Ary       20    7.5        True
# Ana       18    NaN       False
# Cátia     27    2.5       False
# Denis     18    5.0       False
# Beto      21    10.0       True
# Bruna     23    NaN       False
# Dara      21    7.0        True
# Carlos    19    6.0        True
# Alice     35    5.6       False
# Vitor     28    NaN       False
# Daniel    21    NaN       False
# Igor      24    4.5       False
# Sthefanie 26    9.5        True
# Mirla     25    9.0        True
# Paulo     37    NaN       False
# Mylena    29    7.0        True
# Lucas     33    NaN       False
# Nadia     34    8.0        True

# %%
df = pd.read_csv(url,sep=",")
df
# Out:
#                        DataSet:
# Nome      Idade Notas  Aprovado
# Ary       20    7.5        True
# Ana       18    NaN       False
# Cátia     27    2.5       False
# Denis     18    5.0       False
# Beto      21    10.0       True
# Bruna     23    NaN       False
# Dara      21    7.0        True
# Carlos    19    6.0        True
# Alice     35    5.6       False
# Vitor     28    NaN       False
# Daniel    21    NaN       False
# Igor      24    4.5       False
# Sthefanie 26    9.5        True
# Mirla     25    9.0        True
# Paulo     37    NaN       False
# Mylena    29    7.0        True
# Lucas     33    NaN       False
# Nadia     34    8.0        True

# %%
df.head(7)
# Out:
#                    DataSet:
# Nome  Idade Notas  Aprovado
# Ary   20    7.5        True
# Ana   18    NaN       False
# Cátia 27    2.5       False
# Denis 18    5.0       False
# Beto  21    10.0       True
# Bruna 23    NaN       False

# %%
df.tail(5)
# Out:
#               DataSet:
# Mirla  25 9.0     True
# Paulo  37 NaN    False
# Mylena 29 7.0     True
# Lucas  33 NaN    False
# Nadia  34 8.0     True

# %%
df.shape
# Out:
# (19, 1)

# %%
df.info
# Out:
# <bound method DataFrame.info of                        DataSet:
# Nome      Idade Notas  Aprovado
# Ary       20    7.5        True
# Ana       18    NaN       False
# Cátia     27    2.5       False
# Denis     18    5.0       False
# Beto      21    10.0       True
# Bruna     23    NaN       False
# Dara      21    7.0        True
# Carlos    19    6.0        True
# Alice     35    5.6       False
# Vitor     28    NaN       False
# Daniel    21    NaN       False
# Igor      24    4.5       False
# Sthefanie 26    9.5        True
# Mirla     25    9.0        True
# Paulo     37    NaN       False
# Mylena    29    7.0        True
# Lucas     33    NaN       False
# Nadia     34    8.0        True>
